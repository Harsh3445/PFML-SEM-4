# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh3445/PFML-SEM-4/blob/main/time_series_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aim:
# To implement and check Time series functions in python
# Description:
# 1. Through datetime index, perform truncate, duplicates and repeated date colums

# %%
import pandas as pd
import numpy as np
from datetime import datetime
dates = [datetime(2020,1,5),
datetime(2020,1,10),
datetime(2020,1,15),
datetime(2020,1,20),
datetime(2020,1,25)]
ts = pd.Series(np.random.randn(5), index=dates)
print("\nWith this date object, create a series with datetime index:\n",ts)
#<ipython-input-1-d39a36850452>:1: DeprecationWarning:
#Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas
#3.0),
#(to allow more performant data types, such as the Arrow string type, and better interoperability
#with other libraries)
#but was not found to be installed on your system.
#If this would cause problems for you,
#please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
# import pandas as pd
# Out:
# With this date object, create a series with datetime index:
#  2020-01-05    0.120082
# 2020-01-10   -0.102744
# 2020-01-15   -1.134497
# 2020-01-20    0.135153
# 2020-01-25    0.307964
# dtype: float64

# %%
res=ts.truncate(after="1/15/2020")
print("\nTruncate method to truncate datetime series \n", res)
# Out:
# Truncate method to truncate datetime series
#  2020-01-05    0.120082
# 2020-01-10   -0.102744
# 2020-01-15   -1.134497
# dtype: float64

# %%
da=pd.date_range("10/1/2022", periods=10, freq="W-SUN")
print("\nDate range with day periods.\n",da)
# Out:
# Date range with day periods.
#  DatetimeIndex(['2022-10-02', '2022-10-09', '2022-10-16', '2022-10-23',
#                '2022-10-30', '2022-11-06', '2022-11-13', '2022-11-20',
#                '2022-11-27', '2022-12-04'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
date=pd.DatetimeIndex(["1/1/2020","1/2/2020","1/2/2020","1/2/2020","1/3/2020"])
ts1=pd.Series(np.arange(5), index=date)
print("\nDuplicate datetime index:\n",ts1)
# Out:
# Duplicate datetime index:
#  2020-01-01    0
# 2020-01-02    1
# 2020-01-02    2
# 2020-01-02    3
# 2020-01-03    4
# dtype: int64
