# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh3445/PFML-SEM-4/blob/main/data_visualization1%20and%202%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

import numpy as np

Xpoinr=np.array([0,20])
Ypoint=np.array([20,100])
print(plt.plot(Xpoinr,Ypoint))
print(plt.show())
# Out:
# ...
# None

# %%
x = np.array([0,5])
y = np.array([0,25])
print(plt.plot(x,y,marker='p'))
print(plt.show())
# Out:
# ...
# None

# %%
xpoint=np.array([1,3,5,7,9])
ypoiny=np.array([1.2,1.5,5.6,3.5,7.8])
print(plt.plot(xpoint,ypoiny))
print(plt.show())
# Out:
# ...
# None

# %%
import numpy as np
#Title and label
ypoints = np.array([3, 8, 1, 10, 5, 7])
print(plt.plot(ypoints, linestyle='dashed'))
plt.title('Sample graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
print(plt.show())
# Out:
# ...
# None

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])
print(plt.plot(ypoints, marker = 'o'))
print(plt.show())

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

print(plt.plot(xpoints, ypoints, 'violet'))

print(plt.show())
# Out:
# ...
# None
# ...
# None

# %%
print(plt.plot(xpoints, ypoints, linewidth='58', color='c'))
print(plt.show())

#Multiple lines and grid
y1 = np.array([3, 8, 1, 10])
y2 = np.array([3,4,5,6])

print(plt.plot(y1))
print(plt.plot(y2))

plt.grid()
print(plt.show())
# Out:
# ...
# None
# ...
# None

# %%
#plot 2
x= np.array([1, 2, 6, 8])
y= np.array([3, 8, 1, 10])
plt.subplot(1,2,2)
plt.scatter(x, y)
plt.show()

# %%
#scatter 1
a=np.array([5, 7, 9,10])
b=np.array([2, 5, 8,2])
plt.scatter(a,b)
plt.show()
